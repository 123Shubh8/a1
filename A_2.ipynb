# %%
import pandas as pd

# %%
df = pd.read_csv("Academic-Performance-Dataset.csv")

# %%
df.describe()
# Out:
#          Rollno  Attendence  Phy_marks   Che_marks   EM1_marks  PPS_marks  \
# count  20.00000   20.000000  19.000000   17.000000   18.000000  19.000000
# mean   10.50000   75.100000  63.421053   80.764706   83.444444  60.736842
# std     5.91608   14.660724  34.940133   13.690916   11.078449  43.598983
# min     1.00000   53.000000 -34.000000   51.000000   63.000000 -99.000000
# 25%     5.75000   63.750000  59.000000   70.000000   75.750000  56.000000
# 50%    10.50000   73.000000  67.000000   83.000000   83.000000  66.000000
# 75%    15.25000   87.000000  88.000000   93.000000   93.000000  87.500000
# max    20.00000   98.000000  99.000000  100.000000  100.000000  99.000000
#
#        SME_marks  Total Marks  Percentage
# count  20.000000    20.000000   20.000000
# mean   62.700000   327.150000   65.430000
# std    24.891554    78.951867   15.790373
# min    23.000000   192.000000   38.400000
# 25%    42.750000   279.750000   55.950000
# 50%    60.500000   338.000000   67.600000
# ...

# %%
df.isnull().sum()
# Out:
# Rollno         0
# Name           2
# Gender         0
# Branch         0
# Attendence     0
# Phy_marks      1
# Che_marks      3
# EM1_marks      2
# PPS_marks      1
# SME_marks      0
# Total Marks    0
# Percentage     0
# dtype: int64

# %%
df["Phy_marks"] = df["Phy_marks"].fillna(80.764706	)

# %%
df
# Out:
#     Rollno       Name Gender Branch  Attendence  Phy_marks  Che_marks  \
# 0        1   Mohammed      M   Comp        72.0  62.000000       98.0
# 1        2    Reyansh      M     IT        58.0  62.000000       83.0
# 2        3      Aarav      M     IT        57.0 -20.000000      100.0
# 3        4     Atharv      M     IT        60.0  89.000000       83.0
# 4        5     Vivaan      M   Comp        85.0  90.000000        NaN
# 5        6      Advik      M   ENTC        94.0  99.000000       84.0
# 6        7       Ansh      M   ENTC        98.0  88.000000       95.0
# 7        8     Ishaan      M   ENTC        75.0  66.000000       51.0
# 8        9      Dhruv      M   ENTC        63.0  80.764706        NaN
# 9       10  Siddharth      M   ENTC        96.0  67.000000       78.0
# 10      11     Vihaan      M   ENTC        82.0  54.000000       70.0
# 11      12        NaN      M     IT        75.0  64.000000       67.0
# ...

# %%
df.isnull().sum()
# Out:
# Rollno         0
# Name           2
# Gender         0
# Branch         0
# Attendence     0
# Phy_marks      0
# Che_marks      3
# EM1_marks      2
# PPS_marks      1
# SME_marks      0
# Total Marks    0
# Percentage     0
# dtype: int64

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
dp = df[df["Phy_marks"] > 20]

# %%
dp
# Out:
#     Rollno       Name Gender Branch  Attendence  Phy_marks  Che_marks  \
# 0        1   Mohammed      M   Comp        72.0  62.000000       98.0
# 1        2    Reyansh      M     IT        58.0  62.000000       83.0
# 3        4     Atharv      M     IT        60.0  89.000000       83.0
# 4        5     Vivaan      M   Comp        85.0  90.000000        NaN
# 5        6      Advik      M   ENTC        94.0  99.000000       84.0
# 6        7       Ansh      M   ENTC        98.0  88.000000       95.0
# 7        8     Ishaan      M   ENTC        75.0  66.000000       51.0
# 8        9      Dhruv      M   ENTC        63.0  80.764706        NaN
# 9       10  Siddharth      M   ENTC        96.0  67.000000       78.0
# 10      11     Vihaan      M   ENTC        82.0  54.000000       70.0
# 11      12        NaN      M     IT        75.0  64.000000       67.0
# 12      13     Aarush      M     IT        67.0  56.000000       81.0
# ...

# %%
dp.boxplot()
# Out:
# <Axes: >
