# %%
import seaborn as sb
import matplotlib.pyplot as plt

# %%
sb.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sb.load_dataset('titanic')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sb.drop('who',axis =1,inplace = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-23cae5a979bf> in <cell line: 1>()
# ----> 1 sb.drop('who',axis =1,implace = True)
#
# AttributeError: module 'seaborn' has no attribute 'drop'

# %%
df = sb.load_dataset('titanic')

# %%
df.drop('who',axis =1,inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-a7a474d927ff> in <cell line: 1>()
# ----> 1 df.drop('who',axis =1,inplace = True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
sb.load_dataset('titanic')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#      adult_male deck  embark_town alive  alone
# ...

# %%
df.drop(['pclass','embarked'],axis =1,inplace = True)

# %%
df
# Out:
#      survived     sex   age  sibsp  parch     fare   class  adult_male deck  \
# 0           0    male  22.0      1      0   7.2500   Third        True  NaN
# 1           1  female  38.0      1      0  71.2833   First       False    C
# 2           1  female  26.0      0      0   7.9250   Third       False  NaN
# 3           1  female  35.0      1      0  53.1000   First       False    C
# 4           0    male  35.0      0      0   8.0500   Third        True  NaN
# ..        ...     ...   ...    ...    ...      ...     ...         ...  ...
# 886         0    male  27.0      0      0  13.0000  Second        True  NaN
# 887         1  female  19.0      0      0  30.0000   First       False    B
# 888         0  female   NaN      1      2  23.4500   Third       False  NaN
# 889         1    male  26.0      0      0  30.0000   First        True    C
# 890         0    male  32.0      0      0   7.7500   Third        True  NaN
#
#      embark_town alive  alone
# ...

# %%
df.drop(['alive','alone'],axis=1,inplace=True)

# %%
df
# Out:
#      survived     sex   age  sibsp  parch     fare   class  adult_male deck  \
# 0           0    male  22.0      1      0   7.2500   Third        True  NaN
# 1           1  female  38.0      1      0  71.2833   First       False    C
# 2           1  female  26.0      0      0   7.9250   Third       False  NaN
# 3           1  female  35.0      1      0  53.1000   First       False    C
# 4           0    male  35.0      0      0   8.0500   Third        True  NaN
# ..        ...     ...   ...    ...    ...      ...     ...         ...  ...
# 886         0    male  27.0      0      0  13.0000  Second        True  NaN
# 887         1  female  19.0      0      0  30.0000   First       False    B
# 888         0  female   NaN      1      2  23.4500   Third       False  NaN
# 889         1    male  26.0      0      0  30.0000   First        True    C
# 890         0    male  32.0      0      0   7.7500   Third        True  NaN
#
#      embark_town
# 0    Southampton
# 1      Cherbourg
# ...

# %%
df.drop(890,axis= 0)
# Out:
#      survived     sex   age  sibsp  parch     fare   class  adult_male deck  \
# 0           0    male  22.0      1      0   7.2500   Third        True  NaN
# 1           1  female  38.0      1      0  71.2833   First       False    C
# 2           1  female  26.0      0      0   7.9250   Third       False  NaN
# 3           1  female  35.0      1      0  53.1000   First       False    C
# 4           0    male  35.0      0      0   8.0500   Third        True  NaN
# ..        ...     ...   ...    ...    ...      ...     ...         ...  ...
# 885         0  female  39.0      0      5  29.1250   Third       False  NaN
# 886         0    male  27.0      0      0  13.0000  Second        True  NaN
# 887         1  female  19.0      0      0  30.0000   First       False    B
# 888         0  female   NaN      1      2  23.4500   Third       False  NaN
# 889         1    male  26.0      0      0  30.0000   First        True    C
#
#      embark_town
# 0    Southampton
# 1      Cherbourg
# ...

# %%
df.drop(890,axis= 0,inplace = True)

# %%
df
# Out:
#      survived     sex   age  sibsp  parch     fare   class  adult_male deck  \
# 0           0    male  22.0      1      0   7.2500   Third        True  NaN
# 1           1  female  38.0      1      0  71.2833   First       False    C
# 2           1  female  26.0      0      0   7.9250   Third       False  NaN
# 3           1  female  35.0      1      0  53.1000   First       False    C
# 4           0    male  35.0      0      0   8.0500   Third        True  NaN
# ..        ...     ...   ...    ...    ...      ...     ...         ...  ...
# 885         0  female  39.0      0      5  29.1250   Third       False  NaN
# 886         0    male  27.0      0      0  13.0000  Second        True  NaN
# 887         1  female  19.0      0      0  30.0000   First       False    B
# 888         0  female   NaN      1      2  23.4500   Third       False  NaN
# 889         1    male  26.0      0      0  30.0000   First        True    C
#
#      embark_town
# 0    Southampton
# 1      Cherbourg
# ...

# %%
sb.countplot(x='sex',data = df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sb.countplot(x='age',data = df)
# Out:
# <Axes: xlabel='age', ylabel='count'>

# %%
data=df.head(10)
data
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
p_data= data['fare']
plt.pie(p_data,labels = data['embark_town'])
plt.show()

# %%
p_data= df['fare']
plt.pie(p_data,labels = df['embark_town'])
plt.show()

# %%
plt.hist(p_data)
plt.show()

# %%
dt = df.pivot_table(index="embark_town",columns="fare",values="survived")
sb.heatmap(dt,cmap = "YlGnBu",annot= True)
plt.show()

# %%
dt = data.pivot_table(index="embark_town",columns="fare",values="survived")
sb.heatmap(dt,cmap = "BrBG",annot= True)
plt.show()

# %%
sb.pairplot(df, hue='fare', markers=['o', 's'], palette='husl')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (2) than needed (248) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (2) than needed (248) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (2) than needed (248) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (2) than needed (248) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# ...

# %%
sb.pairplot(data, hue='fare', markers=['o', 's'], palette='husl')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (2) than needed (10) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (2) than needed (10) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (2) than needed (10) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (2) than needed (10) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# ...

# %%
sb.scatterplot(data = df, x = 'class',y = 'fare')
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
dt = df.pivot_table(index = 'survived',columns="embark_town",values="age")
dt= dt.fillna(0)
cmap_values = [
    (0, 0, 0, 1),   # Black
    (0, 0.5, 0, 1), # Dark green
    (0, 1, 1, 1),   # Light green
]

sb.clustermap(dt,cmap=cmap_values,annot =True)

# %%
sb.lineplot(data=df,x='age',y='fare')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sb.pointplot(x='class',y='fare',data=df)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
sb.barplot(x='class',y='fare',hue='who',data = df)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
sb.boxplot(x='who',y='age',data=df)
# Out:
# <Axes: xlabel='who', ylabel='age'>

# %%
sb.distplot(df['fare'])
# Out:
# <ipython-input-18-fab7ef8e8038>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(df['fare'])
# <Axes: xlabel='fare', ylabel='Density'>

# %%
sb.pairplot(df, hue='who', markers=['o', 's'], palette='husl')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (2) than needed (3) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (2) than needed (3) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (2) than needed (3) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (2) than needed (3) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# ...

# %%
sb.scatterplot(x='fare', y='who', data=df)
# Out:
# <Axes: xlabel='fare', ylabel='who'>
